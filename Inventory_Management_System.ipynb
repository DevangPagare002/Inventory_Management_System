# %% [markdown]
# # Assignment 1 - JSON based inventory management system

# %% [markdown]
# ## Importing required module

# %%
import json

# %% [markdown]
# ## Total 30 items are pre-registered into the inventory

# %% [markdown]
# ## Note -  Price is in Rs.

# %%
record = {"1001": {'name': "Choco Cake", "price": 100, "quan": 100, "weight": '1 KG', 'color': 'brown', "gst %": 1.5},
          "1002": {"name": "Milk Cake", "price": 800, "quan": 100, 'weight': '2 KG', 'color': 'white', "gst %": 1.5},
          "1003": {"name": "Drink", "price": 50, "quan": 90, "weight": '250 Gm', 'color': 'black', "gst %": 18}, 
          "1004": {"name": "Candy", "price": 5, "quan": 1000, "weight": '20 Gm', 'color': 'brown', "gst %": 3}, 
          "1005": {"name": "Pen", "price": 20, "quan": 100, "weight": '40 Gm', 'color': 'blue', "gst %": 3}, 
          "1006": {"name": "Phone", "price": 50000, "quan": 10, "weight": '650 Gm', 'color': 'Red', "gst %": 8}, 
          "1007": {"name": "Mic", "price": 4000, "quan": 10, "weight": '850 Gm', 'color': 'black', "gst %": 5}, 
          "1008": {"name": "Case", "price": 599, "quan": 15, "weight": '1 KG', 'color': 'silver', "gst %": 1}, 
          "1009": {"name": "Keyboard", "price": 1999, "quan": 10, "weight": '500 Gm', 'color': 'black', "gst %": 5},
          "1010": {"name": "Monitor", "price": 15000, "quan": 20, "weight": '1.5 KG', 'color': 'black', "gst %": 8},
          "1011": {"name": "chair", "quan": 32, "price": 1000, "weight": '2 KG', 'color': 'brown', "gst %": 3}, 
          "1012": {"name": "Plates", "price": 100, "quan": 100, "weight": '200 Gm', 'color': 'white', "gst %": 12.5}, 
          "1013": {"name": "table", "price": 7000, "quan": 100, "weight": '6 KG', 'color': 'brown', "gst %": 5}, 
          "1014": {"name": "Mouse", "price": 1000, "quan": 60, "weight": '300 Gm', 'color': 'black', "gst %": 3}, 
          "1015": {"name": "charger", "price": 500, "quan": 100, "weight": '150 Gm', 'color': 'white', "gst %": 1.5}, 
          "1016": {"name": "refrigerator", "price": 30000, "quan": 10, "weight": '20 KG', 'color': 'silver', "gst %": 8}, 
          "1017": {"name": "Air_conditioner", "price": 25000, "quan": 10, "weight": '5 KG', 'color': 'white', "gst %": 5}, 
          "1018": {"name": "Television", "price": 25000, "quan": 15, "weight": '5 KG', 'color': 'black', "gst %": 8}, 
          "1019": {"name": "Laptop", "price": 70000, "quan": 10, "weight": '1 KG', 'color': 'silver', "gst %": 12.5},
          "1020": {"name": "Fan", "price": 6000, "quan": 20, "weight": '1.3 KG', 'color': 'brown', "gst %": 3},
          "1021": {"name": "Aquaguard", "quan": 32, "price": 2500, "weight": '1.8 KG', 'color': 'blue', "gst %": 3}, 
          "1022": {"name": "tiffin_box", "price": 450, "quan": 100, "weight": '200 Gm', 'color': 'yellow', "gst %": 1.5}, 
          "1023": {"name": "Washing_machine", "price": 10000, "quan": 13, "weight": '10 KG', 'color': 'Red', "gst %": 13}, 
          "1024": {"name": "bucket", "price": 350, "quan": 20, "weight": '300 Gm', 'color': 'pink', "gst %": 1.5}, 
          "1025": {"name": "wallet", "price": 500, "quan": 65, "weight": '150 Gm', 'color': 'black', "gst %": 1.5}, 
          "1026": {"name": "sofa_set", "price": 37000, "quan": 3, "weight": '15 KG', 'color': 'Blue', "gst %": 5}, 
          "1027": {"name": "Cupboard", "price": 8000, "quan": 8, "weight": '9 KG', 'color': 'pink', "gst %": 1.5}, 
          "1028": {"name": "Juicer", "price": 900, "quan": 15, "weight": '1 KG', 'color': 'white', "gst %": 1.5}, 
          "1029": {"name": "Tablet", "price": 35000, "quan": 10, "weight": '800 Gm', 'color': 'Black', "gst %": 8},
          "1030": {"name": "Cup", "price": 100, "quan": 20, "weight": '100 Gm', 'color': 'White', "gst %": 1.5}}

# %% [markdown]
# ## Printing Records in dictionary format

# %%
record
# Out:
# {'1001': {'name': 'Choco Cake',
#   'price': 100,
#   'quan': 100,
#   'weight': '1 KG',
#   'color': 'brown',
#   'GST %': 1.5},
#  '1002': {'name': 'Milk Cake',
#   'price': 800,
#   'quan': 100,
#   'weight': '2 KG',
#   'color': 'white',
#   'GST %': 1.5},
#  '1003': {'name': 'Drink',
#   'price': 50,
#   'quan': 90,
#   'weight': '250 Gm',
#   'color': 'black',
#   'GST %': 18},
#  '1004': {'name': 'Candy',
#   'price': 5,
#   'quan': 1000,
#   'weight': '20 Gm',
#   'color': 'brown',
#   'GST %': 3},
#  '1005': {'name': 'Pen',
#   'price': 20,
#   'quan': 100,
#   'weight': '40 Gm',
#   'color': 'blue',
#   'GST %': 3},
#  '1006': {'name': 'Phone',
#   'price': 50000,
#   'quan': 10,
#   'weight': '650 Gm',
#   'color': 'Red',
#   'GST %': 8},
#  '1007': {'name': 'Mic',
#   'price': 4000,
#   'quan': 10,
#   'weight': '850 Gm',
#   'color': 'black',
#   'GST %': 5},
#  '1008': {'name': 'Case',
#   'price': 599,
#   'quan': 15,
#   'weight': '1 KG',
#   'color': 'silver',
# ...

# %% [markdown]
# ## Converting Dictionary into string

# %%
js = json.dumps(record)

# %% [markdown]
# ## Creating a file named as IMO_record.json and writing the inventroy data into that file.

# %%
fd = open("IMO_record.json", "w")

fd.write(js)

fd.close()

# %% [markdown]
# ## Printing the String format.

# %%
js
# Out:
# '{"1001": {"name": "Choco Cake", "price": 100, "quan": 100, "weight": "1 KG", "color": "brown", "GST %": 1.5}, "1002": {"name": "Milk Cake", "price": 800, "quan": 100, "weight": "2 KG", "color": "white", "GST %": 1.5}, "1003": {"name": "Drink", "price": 50, "quan": 90, "weight": "250 Gm", "color": "black", "GST %": 18}, "1004": {"name": "Candy", "price": 5, "quan": 1000, "weight": "20 Gm", "color": "brown", "GST %": 3}, "1005": {"name": "Pen", "price": 20, "quan": 100, "weight": "40 Gm", "color": "blue", "GST %": 3}, "1006": {"name": "Phone", "price": 50000, "quan": 10, "weight": "650 Gm", "color": "Red", "GST %": 8}, "1007": {"name": "Mic", "price": 4000, "quan": 10, "weight": "850 Gm", "color": "black", "GST %": 5}, "1008": {"name": "Case", "price": 599, "quan": 15, "weight": "1 KG", "color": "silver", "GST %": 1}, "1009": {"name": "Keyboard", "price": 1999, "quan": 10, "weight": "500 Gm", "color": "black", "GST %": 5}, "1010": {"name": "Monitor", "price": 15000, "quan": 20, "weigh
# ...

# %% [markdown]
# ## Reading data from json file and storing it in variable named dct_record

# %%
fd = open("IMO_record.json", 'r')

txt = fd.read()

fd.close()

dct_record = json.loads(txt)

# %% [markdown]
# ## Printing data from the variable

# %%
dct_record
# Out:
# {'1001': {'name': 'Choco Cake',
#   'price': 100,
#   'quan': 100,
#   'weight': '1 KG',
#   'color': 'brown',
#   'GST %': 1.5},
#  '1002': {'name': 'Milk Cake',
#   'price': 800,
#   'quan': 100,
#   'weight': '2 KG',
#   'color': 'white',
#   'GST %': 1.5},
#  '1003': {'name': 'Drink',
#   'price': 50,
#   'quan': 90,
#   'weight': '250 Gm',
#   'color': 'black',
#   'GST %': 18},
#  '1004': {'name': 'Candy',
#   'price': 5,
#   'quan': 1000,
#   'weight': '20 Gm',
#   'color': 'brown',
#   'GST %': 3},
#  '1005': {'name': 'Pen',
#   'price': 20,
#   'quan': 100,
#   'weight': '40 Gm',
#   'color': 'blue',
#   'GST %': 3},
#  '1006': {'name': 'Phone',
#   'price': 50000,
#   'quan': 10,
#   'weight': '650 Gm',
#   'color': 'Red',
#   'GST %': 8},
#  '1007': {'name': 'Mic',
#   'price': 4000,
#   'quan': 10,
#   'weight': '850 Gm',
#   'color': 'black',
#   'GST %': 5},
#  '1008': {'name': 'Case',
#   'price': 599,
#   'quan': 15,
#   'weight': '1 KG',
#   'color': 'silver',
# ...

# %% [markdown]
# ## Creating a Sales.json file to store all the sales records
#
# ### Sales.json file will contain all the products sold by shop

# %%
sale = {}

sale = json.dumps(sale)

fd = open("Sales.json", 'w')
fd.write(sale)
fd.close()

# %%
fd = open("IMO_record.json", 'r')

txt = fd.read()

fd.close()

fd = open("Sales.json", 'r')
sale = fd.read()
fd.close()
sale = json.loads(sale)


dct_record = json.loads(txt)

print("********************************************************************************************************")
print("************************************** WELCOME TO THE SHOP *********************************************")
print("********************************************************************************************************")
print("********************************************** MENU ****************************************************")
print("")

for i in dct_record:
    print(i, dct_record[i])
    
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("")
ui_prod = input("Enter the ID of product that you want to buy: ")
ui_quat = int(input("\nEnter the quantity of product you want: "))
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
if ui_prod in dct_record.keys():
        
        if int(dct_record[ui_prod]['quan']) >= ui_quat:
            print("Product information - ")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print(f"Name of the product is {dct_record[ui_prod]['name']}")
            print(f"\n {dct_record[ui_prod]['name']} costs {dct_record[ui_prod]['price']} Rs. each ")
            print(f" {dct_record[ui_prod]['gst %']} % GST will be applied.")
            print(f"\nWe have {dct_record[ui_prod]['quan']} quantity available of '{dct_record[ui_prod]['name']}'")
            print("******************************************************************************************")
            print(f"Your total bill is : {(int(dct_record[ui_prod]['price']) * ui_quat) + (((int(dct_record[ui_prod]['price']) * ui_quat) * float(dct_record[ui_prod]['gst %'])) / 100.0)} with {dct_record[ui_prod]['gst %']} % GST added")
        
            dct_record[ui_prod]['quan'] = int(dct_record[ui_prod]['quan']) - ui_quat
        
        else:
            print(f"Sorry but we do not have that much stock left for {dct_record[ui_prod]['name']} ")
            print(f"We only have {dct_record[ui_prod]['quan']} stock left")
            choice = input(f"Will you please reduce your qunatity to {dct_record[ui_prod]['quan']} or less? (Yes/No)")
            
            if choice.lower() == 'yes':
                ui_quat = int(input(f"Enter the new quntity you want (but please keep it below {dct_record[ui_prod]['quan']})"))
                print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
                print(f"Name of the product is {dct_record[ui_prod]['name']}")
                print(f"Product {dct_record[ui_prod]['name']} costs {dct_record[ui_prod]['price']} Rs. each ")
                print(f"We have {dct_record[ui_prod]['quan']} quantity available of '{dct_record[ui_prod]['name']}'")
                print("******************************************************************************************")
                print(f"Your total bill is : {(int(dct_record[ui_prod]['price']) * ui_quat) + (((int(dct_record[ui_prod]['price']) * ui_quat) * float(dct_record[ui_prod]['gst %'])) / 100.0)} with {dct_record[ui_prod]['gst %']} % GST added")
        
                dct_record[ui_prod]['quan'] = int(dct_record[ui_prod]['quan']) - int(ui_quat)
            else:
                    pass
        print("\nItem purchased successfully!!!")

js = json.dumps(dct_record)

fd = open("IMO_record.json", 'w')

fd.write(js)

fd.close()
# Out:
# ********************************************************************************************************
# ************************************** WELCOME TO THE SHOP *********************************************
# ********************************************************************************************************
# ********************************************** MENU ****************************************************
#
# 1001 {'name': 'Choco Cake', 'price': 100, 'quan': 100, 'weight': '1 KG', 'color': 'brown', 'gst %': 1.5}
# 1002 {'name': 'Milk Cake', 'price': 800, 'quan': 100, 'weight': '2 KG', 'color': 'white', 'gst %': 1.5}
# 1003 {'name': 'Drink', 'price': 50, 'quan': 90, 'weight': '250 Gm', 'color': 'black', 'gst %': 18}
# 1004 {'name': 'Candy', 'price': 5, 'quan': 1000, 'weight': '20 Gm', 'color': 'brown', 'gst %': 3}
# 1005 {'name': 'Pen', 'price': 20, 'quan': 100, 'weight': '40 Gm', 'color': 'blue', 'gst %': 3}
# ...

# %% [markdown]
# ## Creating Sales records

# %%
import time

# fd = open("purchases.json", 'r')
# purc = fd.read()
# fd.close()
# purchase = json.loads(purc)

# fd = open("purchases.json", 'r')
# text = fd.read()
# fd.close()

# purchases = json.loads(text)

sale[str(len(sale) + 1)] = {'Id': ui_prod, 'name': dct_record[ui_prod]['name'], 'quantity': ui_quat, 'time_of_order': time.ctime(), 'price': (int(dct_record[ui_prod]['price']) * ui_quat) + (((int(dct_record[ui_prod]['price']) * ui_quat) * float(dct_record[ui_prod]['gst %'])) / 100.0)}
# pur = json.dumps(purchases)w
# fd = open("purchases.json", 'a')
# fd.write(pur)
# fd.close()
# print("Reports are created in sales.json") 

sl = json.dumps(sale)                                                          # Updating Sales File
fd = open('Sales.json','w')
fd.write(sl)
fd.close()

# %% [markdown]
# ## Reading Sales records

# %%
fd = open('Sales.json', 'r')
txt = fd.read()
fd.close()

Sales_record = json.loads(txt)

Sales_record
# Out:
# {'1': {'Id': '1002',
#   'name': 'Milk Cake',
#   'quantity': 10,
#   'time_of_order': 'Thu Sep 16 16:40:15 2021',
#   'price': 8120.0}}

# %% [markdown]
# ## Now, if the user wants to sell something to the shop, he can do it with following code

# %%
purchase = {}

purchase = json.dumps(purchase)

fd = open("purchases.json", 'w')
fd.write(purchase)
fd.close()

# %%
import time
a = input("You want to add products in inventory, right? (yes/no): ")
    
fd = open("purchases.json", 'r')
purchase = fd.read()
fd.close()
purchase = json.loads(purchase)
    
fd = open("IMO_record.json", 'r')

txt = fd.read()

fd.close()
    
dct_record = json.loads(txt)
    
if a.lower() == 'yes':

    
    prod_id = input("Enter product ID: ")
    name = input("Enter name of product: ")
    price = int(input("Enter price of product: "))
    quan = int(input("Enter quantity of product: "))
    weight = input("Enter weight of product: ")
    color = input("Enter color of product: ")
#    gst = float(input("Enter GST percentage: "))
#    dct_record[prod_id] = {'name': name, 'price': price, 'quan': quan, "weight": weight, "color": color}
    if (prod_id in dct_record.keys()) and (name == dct_record[prod_id]['name']) and (price == dct_record[prod_id]['price']) and (gst == dct_record[prod_id]["gst %"]):
        
        dct_record[prod_id]['quan'] = int(dct_record[prod_id]['quan']) + int(quan)
#        dct_record[ui_prod]['quan'] = str(int(dct_record[ui_prod]['quan']) - int(ui_quat))
#        purchase[str(len(purchase) + 1)] = {'Id': ui_prod, 'name': dct_record[ui_prod]['name'], 'quantity': ui_quat, 'time_of_order': time.ctime(), 'price': dct_record[ui_prod]['price'] * int(ui_quat)}
    
    else:
        dct_record[prod_id] = {'name': name, 'price': price, 'quan': quan, "weight": weight, "color": color}
        
#        purchase[str(len(purchase) + 1)] = {'Id': prod_id, 'name': name, 'quantity': quan, 'time_of_order': time.ctime(), 'price': int(price) * int(quan)}
    
    print("product successfully added into inventory!")
    
    purchase[str(len(purchase) + 1)] = {'Id': prod_id, 'name': name, 'quantity': quan, 'time_of_order': time.ctime(), 'price': (price * quan)}
    
    js = json.dumps(dct_record)

    fd = open("IMO_record.json", 'w')

    fd.write(js)

    fd.close()

    purchase = json.dumps(purchase)                                                          # Updating Sales File
    fd = open('purchases.json','w')
    fd.write(purchase)
    fd.close()

    
else:
        
    pass

# purchase[str(len(purchase) + 1)] = {'Id': prod_id, 'name': name, 'quantity': quan, 'time_of_order': time.ctime(), 'price': int(price) * int(quan)}
# js = json.dumps(dct_record)

# fd = open("IMO_record.json", 'w')

# fd.write(js)

# fd.close()

# purchase = json.dumps(purchase)                                                          # Updating Sales File
# fd = open('purchases.json','w')
# fd.write(pur)
# fd.close()
# Out:
# You want to add products in inventory, right? (yes/no): yes
# Enter product ID: 1032
# Enter name of product: tanmay
# Enter price of product: 9
# Enter quantity of product: 1
# Enter weight of product: 4 KG
# Enter color of product: aefua
# product successfully added into inventory!

# %%
fd = open("purchases.json", 'r')
purchase = fd.read()
fd.close()
purchase = json.loads(purchase)

print(purchase)
# Out:
# {'1': {'Id': '1031', 'name': 'abc', 'quantity': 12, 'time_of_order': 'Thu Sep 16 16:42:49 2021', 'price': 952.848}, '2': {'Id': '1032', 'name': 'tanmay', 'quantity': 1, 'time_of_order': 'Thu Sep 16 16:50:52 2021', 'price': 9}}
